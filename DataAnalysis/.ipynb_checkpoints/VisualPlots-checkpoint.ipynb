# %%
import numpy as np                                  # Imported for linear algebra
import pandas as pd                                 # Imported for data processing
import matplotlib.pyplot as plt                     # Imported for plotting library
import random
import plotly as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
import seaborn as sns 
import matplotlib.patches as mpatches
import plotly.plotly as py
import plotly.graph_objs as go

# %%
MockDataA = {'Sprint' : [1], 'Index': [1], 'SPR': [800], 'DayWork' : ['Preparation']}
MockDFActual = pd.DataFrame(data=MockDataA)
MockDFActual
# Out:
#        DayWork  Index  SPR  Sprint
# 0  Preparation      1  800       1

# %%
MockDataE = {'Sprint' : [1], 'Index': [1], 'SPR': [800], 'DayWork' : ['Preparation']}
MockDFExpected = pd.DataFrame(data=MockDataE)
MockDFExpected
# Out:
#        DayWork  Index  SPR  Sprint
# 0  Preparation      1  800       1

# %%
def addToDataFrame(dataFrame, sprint, idx, spRemaining, dayWork):
    return dataFrame.append({'Sprint' : sprint, 'Index': idx, 'SPR': spRemaining, 'DayWork' : dayWork}, ignore_index=True)

# %%
import random

sp = 800
daywork = 'Preparation'

for x in range(2, 32):
    if (x > 5 and x < 14): daywork = 'Programming'
    if (x > 14 and x < 19): daywork = 'Drinking Beer'
    if (x > 20 and x < 33): daywork = 'Eating Pizza'
    sp = sp-random.randint(3,12)
    MockDFActual = addToDataFrame(MockDFActual, 1, x, sp, daywork)

MockDFActual
# Out:
#           DayWork  Index  SPR  Sprint
# 0     Preparation      1  800       1
# 1     Preparation      2  788       1
# 2     Preparation      3  781       1
# 3     Preparation      4  769       1
# 4     Preparation      5  761       1
# 5     Programming      6  754       1
# 6     Programming      7  743       1
# 7     Programming      8  737       1
# 8     Programming      9  730       1
# 9     Programming     10  724       1
# 10    Programming     11  713       1
# 11    Programming     12  705       1
# 12    Programming     13  702       1
# 13    Programming     14  694       1
# 14  Drinking Beer     15  688       1
# 15  Drinking Beer     16  683       1
# 16  Drinking Beer     17  671       1
# 17  Drinking Beer     18  660       1
# 18  Drinking Beer     19  648       1
# 19  Drinking Beer     20  644       1
# 20   Eating Pizza     21  636       1
# 21   Eating Pizza     22  626       1
# 22   Eating Pizza     23  616       1
# 23   Eating Pizza     24  611       1
# ...

# %%
import random

sp = 800
daywork = 'Preparation'

for x in range(2, 32):
    if (x > 5 and x < 14): daywork = 'Programming'
    if (x > 14 and x < 19): daywork = 'Drinking Beer'
    if (x > 20 and x < 33): daywork = 'Eating Pizza'
    sp = sp-random.randint(5,14)
    MockDFExpected = addToDataFrame(MockDFExpected, 1, x, sp, daywork)

MockDFExpected
# Out:
#           DayWork  Index  SPR  Sprint
# 0     Preparation      1  800       1
# 1     Preparation      2  791       1
# 2     Preparation      3  777       1
# 3     Preparation      4  768       1
# 4     Preparation      5  755       1
# 5     Programming      6  746       1
# 6     Programming      7  735       1
# 7     Programming      8  727       1
# 8     Programming      9  722       1
# 9     Programming     10  716       1
# 10    Programming     11  706       1
# 11    Programming     12  694       1
# 12    Programming     13  680       1
# 13    Programming     14  669       1
# 14  Drinking Beer     15  664       1
# 15  Drinking Beer     16  653       1
# 16  Drinking Beer     17  640       1
# 17  Drinking Beer     18  629       1
# 18  Drinking Beer     19  620       1
# 19  Drinking Beer     20  606       1
# 20   Eating Pizza     21  597       1
# 21   Eating Pizza     22  592       1
# 22   Eating Pizza     23  582       1
# 23   Eating Pizza     24  569       1
# ...

# %%
def plotBurndownChart (prioritySP, AllSP) :
    # Initialize the figure
    plt.style.use('seaborn-darkgrid')

    plt.figure(figsize = (13, 6)) 
 
    # create a color palette
    palette = plt.get_cmap('Set1')
    x1 = prioritySP['Index']
    y1 = prioritySP['SPR']

    x2 = AllSP['Index']
    y2 = AllSP['SPR']

    AColor = '#99ffeb'
    AAColor = '#00cca3'
    EColor = '#ffcc99'
    EEColor = '#ff9933'

    # Plot the lineplot
    plt.plot(x1, y1, '--',
             marker='',
             color=EColor,
             linewidth=1.9,
             label=prioritySP.SPR)

    plt.plot(x2, y2,
             marker='',
             color=AAColor,
             linewidth=1.9,
             label=AllSP.SPR)

    plt.fill_between(x1, y2, color=AColor, alpha='0.6')
    plt.fill_between(x2, y1, color=EColor, alpha='0.1')

    plt.ylim(0,1000)
    plt.xlim(1,31)

    all_patch = mpatches.Patch(color=EEColor, label='Total Remaining Story Points')
    priority_patch = mpatches.Patch(color=AAColor, label='Remaining Top Priority Story Points')

    plt.legend(handles=[all_patch, priority_patch])
    plt.title('Burndown Progress Chart', fontsize=17)
    plt.ylabel('Story Points', fontsize=10)

# %%
plotBurndownChart (MockDFActual, MockDFExpected)

ax = plt.gca()
ax.set_yticks([200,400,600,800,1000])
ax.set_xticks([1,31])
ax.set_xticklabels(["Sprint 0","Sprint 1"])
plt.xticks(fontsize=12, rotation=30)

plt.show()

# %%
Day = 0
initialStoryPoints = 800
initialPriorityStoryPoints = 600

ActualData = {'Day' : [Day], 'Sprint' : [1], 'SPR' : [initialStoryPoints], 'PSPR' : [initialPriorityStoryPoints], 'DayWork' : ['Preparation']}
ActualData = pd.DataFrame(data=ActualData)

# %%
def updateDF(DF, sprint, SPRemaining, prioritySPRemaining, workdone):
    return DF.append({'Day' : len(ActualData.index), 'Sprint' : sprint, 'SPR' : SPRemaining, 'PSPR' : prioritySPRemaining, 'DayWork' : workdone}, ignore_index=True)

# %%
# UPDATES ACTUAL DATA!!
# updateDF Param:
# ActualData dataframe,
# no of sprint,
# total story points remaining
# total priority story points remaining
# Work done as category
ActualData = updateDF (ActualData, 1, 788, 598, 'Preparation')
ActualData
# Out:
#    Day      DayWork  PSPR  SPR  Sprint
# 0    0  Preparation   600  800       1
# 1    1  Preparation   598  788       1

# %%
def undoLastEntry(DF):
    return DF.drop(DF.index[len(DF)-1])

# %%
# UNDOES LAST ENTRY!!
# updateDF Param:
# ActualData dataframe,
#ActualData = 
ActualData = undoLastEntry(ActualData)
ActualData
# Out:
#    Day      DayWork  PSPR  SPR  Sprint
# 0    0  Preparation   600  800       1
